# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
avg500_df = pd.read_csv('csv/avg_500.csv')
avg_25000_df = pd.read_csv('csv/avg_25000.csv')

# %%
sns.set_context("paper")

# %%
plt.figure(figsize=(10,5))
avg500_plot = sns.scatterplot(x='threads_maximo',y='time', data=avg500_df)
avg500_plot = avg500_plot.set(xticks=range(31))
plt.ylabel('time (ms)')
plt.xlabel('threads')
plt
#avg500_plot = avg500_plot.set_xticklabels(rotation=45)
# Out:
# Text(0, 0.5, 'time (ns)')
